# %% [markdown]
# # (Multi)Polygon `_duplicated_exterior_coordinates_list`
# Function returns a list of duplicated exterior coordinates for (Multi)LineString features.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os

os.getcwd()
# Out:
# '/home/lukasz/Projects/geonurse/notebooks'

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import MultiPoint

from geonurse.tools.polygon import has_exterior_duplicates, _duplicated_exterior_coordinates_list

# %% [markdown]
# ## Load data

# %%
DATA_PATH = '../tests/tools/polygon/data/exterior'

# %% [markdown]
# ### Features with duplicates

# %% [markdown]
# #### Read data

# %%
polygons_with_duplicates = gpd.read_file(os.path.join(DATA_PATH, 'expected_polygon_with_exterior_duplicates.geojson'))

# %%
polygons_with_duplicates.head()
# Out:
#    id                                           geometry
# 0   0  POLYGON ((151 -285, 352 -279, 352 -279, 364 -3...
# 1   1  (POLYGON ((-43.99851510731804 50.9361132418613...
# 2   2  POLYGON ((435.8477564102565 -284.7503205128205...
# 3   3  POLYGON ((241.8759615384615 -29.32211538461519...
# 4   4  POLYGON ((483.860576923077 -29.32211538461519,...

# %% [markdown]
# #### Plot data

# %%
ax = polygons_with_duplicates.plot(figsize=(20,20), column='id', cmap='plasma')

polygons_with_duplicates.apply(lambda x: ax.annotate(s=x.id, xy=x.geometry.centroid.coords[0], ha='center'), axis=1)
print()

# %% [markdown]
# #### Find duplicates

# %%
duplicated_coordinates = (
    polygons_with_duplicates.geometry
        .apply(_duplicated_exterior_coordinates_list)
        .apply(MultiPoint)
)

assert len(polygons_with_duplicates) == len(duplicated_coordinates)

# %%
duplicated_coordinates
# Out:
# 0                 (POINT (352 -279), POINT (364 -362))
# 1    (POINT (77.42023093128762 61.49426507130534), ...
# 2       (POINT (547.2375000000002 -355.8092948717949))
# 3       (POINT (349.4246794871795 -123.4272435897435))
# 4       (POINT (543.3964743589745 -27.40160256410235))
# 5       (POINT (774.2582516745898 -213.0176824942379))
# 6    (POINT (373.0484821557188 24.54073366825145), ...
# 7         (POINT (314.978647093777 -524.483161462835))
# Name: geometry, dtype: object

# %% [markdown]
# #### Plot filtered geometries

# %%
ax = duplicated_coordinates.plot(figsize=(20,20), marker='o', markersize=80) #, column='id', cmap='plasma')

polygons_with_duplicates.plot(ax=ax, column='id', cmap='plasma')

polygons_with_duplicates.apply(lambda x: ax.annotate(s=x.id, xy=x.geometry.centroid.coords[0], ha='center'), axis=1)
print()

# %% [markdown]
# #### Compare with EXPECTED data

# %%
expected_duplicates = gpd.read_file(os.path.join(DATA_PATH, 'expected_polygon_exterior_duplicates.geojson'))

# %%
expected_duplicates
# Out:
#     FEAT_ID                                     ERROR  \
# 0         0  line 0 contains 1 duplicate node(s) at 1
# 1         0  line 0 contains 1 duplicate node(s) at 2
# 2         1  line 0 contains 1 duplicate node(s) at 2
# 3         2  line 0 contains 1 duplicate node(s) at 3
# 4         3  line 0 contains 1 duplicate node(s) at 1
# 5         6  line 0 contains 1 duplicate node(s) at 2
# 6         8  line 0 contains 1 duplicate node(s) at 2
# 7         9  line 0 contains 1 duplicate node(s) at 1
# 8        10  line 0 contains 1 duplicate node(s) at 2
# 9        12  line 0 contains 1 duplicate node(s) at 1
# 10       13  line 0 contains 1 duplicate node(s) at 1
#
#                                         geometry
# 0                               POINT (352 -279)
# 1                               POINT (364 -362)
# 2   POINT (547.2375000000002 -355.8092948717949)
# 3   POINT (349.4246794871795 -123.4272435897435)
# 4   POINT (543.3964743589745 -27.40160256410235)
# 5   POINT (774.2582516745898 -213.0176824942379)
# 6    POINT (373.0484821557188 24.54073366825145)
# 7    POINT (571.0138289577933 116.9245621758862)
# 8     POINT (314.978647093777 -524.483161462835)
# 9    POINT (77.42023093128762 61.49426507130534)
# 10  POINT (93.25745867545356 -112.7152401145202)

# %% [markdown]
# NOTE:
# In order to compare the result `duplicated_coordinates` geopandas.GeoSeries has to be exploded. This will split multipart features into singlepart onces.

# %%
assert len(expected_duplicates) == len(duplicated_coordinates.explode())

# %%
duplicated_coordinates_geoseries = gpd.GeoSeries(
    duplicated_coordinates
        .explode()
        .reset_index()
        .drop(['level_0', 'level_1'], axis=1)
        .geometry
)

# %%
duplicated_coordinates_geoseries.unary_union

# %%
expected_duplicates.geometry.unary_union == duplicated_coordinates_geoseries.unary_union
# Out:
# True
